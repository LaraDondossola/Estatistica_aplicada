# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraDondossola/Estatistica_aplicada/blob/main/lista002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import Series
from pandas import DataFrame

# %%
dicionario = {'nome' : ['Joao', 'Maria', 'Pedro', 'Ana'],
        'idade' : [25, 30, 25, 40],
        'salário' :[3500,4000,4500,5000]}

frame = DataFrame(dicionario)

frame
# Out:
#     nome  idade  salário
# 0   Joao     25     3500
# 1  Maria     30     4000
# 2  Pedro     25     4500
# 3    Ana     40     5000

# %%
listas = [['João', 25, 3500], ['Maria', 30, 4000], ['Pedro', 35, 4500], ['Ana', 40, 5000]]

frame1 = DataFrame(listas, columns= ['nome', 'idade', 'salário']) #Criar dataFrame com listas

frame1
# Out:
#     nome  idade  salário
# 0   João     25     3500
# 1  Maria     30     4000
# 2  Pedro     35     4500
# 3    Ana     40     5000

# %%
dicionario2 = {'Nome:' : [],
               'Idade' : [],
               'Salário' : []}

frame2 = DataFrame(dicionario2)

frame2 #criando um dataFrame vazio

dados = [['João', 25, 3500],
         ['Maria', 30, 4000],
         ['Pedro', 35, 4500],
         ['Ana', 40, 5000]]

frame3 = DataFrame(dados, columns = ['Nome', 'Idade', 'Salário']) #adicionando os dados no dataFrame

frame3
# Out:
#     Nome  Idade  Salário
# 0   João     25     3500
# 1  Maria     30     4000
# 2  Pedro     35     4500
# 3    Ana     40     5000

# %%
frame['nome']
# Out:
# 0     Joao
# 1    Maria
# 2    Pedro
# 3      Ana
# Name: nome, dtype: object

# %%
frame[['nome', 'idade']] #usar dois [] quando queremos imprimir duas colunas
# Out:
#     nome  idade
# 0   Joao     25
# 1  Maria     30
# 2  Pedro     25
# 3    Ana     40

# %%
frame.iloc[2] #selecionar uma linha pelo índice
# Out:
# nome       Pedro
# idade         25
# salário     4500
# Name: 2, dtype: object

# %%
frame[frame["idade"] > 30] #selecionar linhas com idade > 30
# Out:
#   nome  idade  salário
# 3  Ana     40     5000

# %%
frame["salário anual"] = frame["salário"] * 12 #adicionando uma nova coluna

frame
# Out:
#     nome  idade  salário  salário anual
# 0   Joao     25     3500          42000
# 1  Maria     30     4000          48000
# 2  Pedro     25     4500          54000
# 3    Ana     40     5000          60000

# %%
media_salario = frame.groupby("idade")["salário"].mean() #agrupando idade e adicionando média de salário

media_salario
# Out:
# idade
# 25    4000.0
# 30    4000.0
# 40    5000.0
# Name: salário, dtype: float64

# %%
dicionario3 = {'nome' : ['Joao', 'Maria', 'Pedro', 'Ana', "Carlos"],
        'idade' : [25, 30, 35, None, 45],
        }

frame4 = DataFrame(dicionario3)

frame4.isna()
# Out:
#     nome  idade
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False   True
# 4  False  False

# %%
frame4['idade'] = frame4['idade'].fillna(0) #substitui por zero as idades NULAS

frame4
# Out:
#      nome  idade
# 0    Joao   25.0
# 1   Maria   30.0
# 2   Pedro   35.0
# 3     Ana    0.0
# 4  Carlos   45.0

# %%
dicionario4 = {'nome' : ['Joao', 'Maria', 'Pedro', 'Ana', 'Ana'],
        'idade' : [25, 30, 25, 40, 40],
        'salário' :[3500,4000,4500,5000,5000]}

frame5 = DataFrame(dicionario4)

frame5.drop_duplicates() #removendo duplicatas
# Out:
#     nome  idade  salário
# 0   Joao     25     3500
# 1  Maria     30     4000
# 2  Pedro     25     4500
# 3    Ana     40     5000

# %%
frame["idade"] = frame["idade"].astype(float) #alterando o tipo para float

frame.dtypes
# Out:
# nome              object
# idade            float64
# salário            int64
# salário anual      int64
# dtype: object
